# %%
import pandas as pd
import matplotlib.pyplot as plt

def load_dataset():
    dataset = "https://storage.googleapis.com/qwasar-public/track-ds/boston.csv"
    boston_df = pd.read_csv(dataset)
    return boston_df

# %%
load_dataset()
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  MDEV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
def print_summarize_dataset(dataset):
    print("Dataset dimension:")
    print(dataset.shape)
    print()
    
    print("First 10 rows of dataset:")
    print(dataset.head(10))
    print()
    
    print("Statistical summary:")
    print(dataset.describe())

# %%
ld_data = load_dataset()
sumrze_data = print_summarize_dataset(ld_data)
# Out:
# Dataset dimension:
# (506, 14)
#
# First 10 rows of dataset:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622  3.0  222.0
# 5  0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622  3.0  222.0
# 6  0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605  5.0  311.0
# 7  0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505  5.0  311.0
# 8  0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821  5.0  311.0
# 9  0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921  5.0  311.0
#
#    PTRATIO       B  LSTAT  MDEV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# ...

# %%
def clean_dataset(boston_dataframe):
    cleaned_Data = boston_dataframe.dropna()
    return cleaned_Data

# %%
def  print_histograms(dataframe):
    axes = dataframe.hist(bins=15, figsize=(15, 10))
    plt.tight_layout()
    for ax in axes.flatten():
        ax.set_ylabel("Frequency")
        #ax.set_xlabel("Value")
    plt.show()

# %%
ld_data = load_dataset()
sumrze_data = print_histograms(ld_data)

# %%
def compute_correlations_matrix(boston_dataframe):
    corr_matrx = boston_dataframe.corr()
    return corr_matrx

# %%
ld_data =load_dataset()
correlation = compute_correlations_matrix(ld_data)
print(correlation)
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.199458  0.404471 -0.055295  0.417521 -0.219940  0.350784
# ZN      -0.199458  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.404471 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055295 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.417521 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219940  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.350784 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.377904  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.622029 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.579564 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.288250 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
print(correlation['MDEV'])
# Out:
# CRIM      -0.385832
# ZN         0.360445
# INDUS     -0.483725
# CHAS       0.175260
# NOX       -0.427321
# RM         0.695360
# AGE       -0.376955
# DIS        0.249929
# RAD       -0.381626
# TAX       -0.468536
# PTRATIO   -0.507787
# B          0.333461
# LSTAT     -0.737663
# MDEV       1.000000
# Name: MDEV, dtype: float64

# %%
from pandas.plotting import scatter_matrix


def print_scatter_matrix(dataframe):
    # Create the scatter matrix plot
    plt.figure(figsize=(15, 15))
    scatter_matrix(dataframe, alpha=0.2, diagonal='hist', figsize=(15, 15), s=30, cmap='viridis')
    
    # Set the title of the plot
    plt.suptitle('Scatter Matrix of Dataset', y=1.02)
    
    # Adjust layout to prevent overlap
    plt.tight_layout()
    
    # Show the plot
    plt.show()

# %%
boston_dataframe = load_dataset()
scatter_plt =  print_scatter_matrix(ld_data )
print(scatter_plt)
# Out:
# None

# %%
import sklearn.linear_model
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split


def boston_fit_model(boston_dataframe):
  # SELECT two columns from our
  model_dataset = boston_dataframe[["RM","MDEV"]]
  regressor = LinearRegression()
  # Extract column 1
  x = model_dataset.iloc[:, :-1].values
  # Extract column 2
  y = model_dataset.iloc[:, 1].values
  # Train the model
  regressor.fit(x, y)
  return regressor

# %%
model_dataset = boston_dataframe[["RM","MDEV"]]
fitted_model = boston_fit_model(model_dataset)
print(fitted_model)
# Out:
# LinearRegression()

# %%
def boston_predict(estimator, array_to_predict):
    prediction = estimator.predict(array_to_predict)
    return prediction

# %%
estimator = boston_fit_model(model_dataset)
array_to_predict = ld_data[["RM"]].values
print(boston_predict(estimator, array_to_predict))
# Out:
# [25.17574577 23.77402099 30.72803225 29.02593787 30.38215211 23.85593997
#  20.05125842 21.50759586 16.5833549  19.97844155 23.3735282  20.02395209
#  18.93169901 19.47782555 20.81583557 18.43108302 19.35039603 19.85101202
#  14.99048582 17.45715736 16.02812625 19.6234593  21.23453259 18.23993873
#  19.25027283 16.29208741 18.23993873 20.36983223 24.44757706 26.07685456
#  17.32972783 20.59738496 19.48692766 17.22050253 20.81583557 19.33219181
#  18.49479778 18.57671676 19.63256141 25.35778795 29.26259271 26.95065703
#  21.48028953 21.86257811 20.57007863 17.04756245 17.99418179 20.21509638
#  14.47166561 16.31939374 19.60525508 20.98877564 24.5932108  19.92382889
#  18.9225969  31.31056723 23.42814085 27.36935404 21.26183891 19.27757916
#  17.58458688 19.63256141 24.09259481 26.87784015 29.99076143 22.58164472
#  18.0032839  18.83157581 16.24657686 18.89529058 23.73761256 19.58705086
#  20.53367019 22.17204981 22.42690886 22.54523628 22.48152152 21.21632837
# ...

# %%
from sklearn import metrics
import numpy as np

def print_model_prediction_evaluator(base_test, prediction):
    
    print('Mean Absolute Error:', metrics.mean_absolute_error(base_Test, preDiction))
    print('Mean Squared Error:', metrics.mean_squared_error(base_Test, preDiction))
    print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(base_Test, preDiction)))

# %%
base_test = ld_data[["MDEV"]].values
prediction = boston_predict(estimator, array_to_predict)
print_model_prediction_evaluator(base_test, prediction)
# Out:
# Mean Absolute Error: 4.447772901532233
# Mean Squared Error: 43.60055177116956
# Root Mean Squared Error: 6.603071389222561
